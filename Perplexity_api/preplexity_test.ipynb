# %%
from openai import OpenAI

# %%
API_KEY = "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"

# %%
import openai

messages = [
    {
        "role": "system",
        "content": (
            "You are an artificial intelligence assistant and you need to "
            "engage in a helpful, detailed, polite conversation with a user."
        ),
    },
    {   
        "role": "user",
        "content": (
            "Deepseek將如何影響中國經濟?"
        ),
    },
]

client = OpenAI(api_key=API_KEY, base_url="https://api.perplexity.ai")

# chat completion without streaming
response = client.chat.completions.create(
    model="sonar-pro",
    messages=messages,
)
print(response)

"""
chunks = []

# chat completion with streaming
response_stream = client.chat.completions.create(
    model="sonar",
    messages=messages,
    stream=True,
)
for response in response_stream:
    chunks.append(response)
    print(response) """
# Out:
# ChatCompletion(id='e21b9256-6e64-4343-8486-843de7feb5aa', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='DeepSeek的出現和快速普及可能會對中國經濟產生以下幾方面的影響:\n\n1. 推動AI產業發展:\nDeepSeek作為低成本、高性能的AI模型,可能會加速中國AI產業的發展,促進相關技術創新和應用普及。這可能會帶動AI產業鏈的擴張,創造新的就業機會和經濟增長點。\n\n2. 提高企業生產效率:\n許多企業正在接入DeepSeek等AI系統,這可能會顯著提高企業的生產效率和競爭力。通過AI自動化一些工作流程,企業可以降低成本、提高效率。\n\n3. 推動政務智能化:\n一些地方政府正在將DeepSeek應用於政務系統,這可能會提高政府工作效率,改善公共服務質量。\n\n4. 加速產業升級:\nAI技術的廣泛應用可能會加速中國產業的智能化升級,推動傳統產業向高附加值方向轉型。\n\n5. 引發就業結構變化:\nAI的普及可能會取代一些低技能崗位,同時也會創造新的就業機會。這可能會引發就業結構的調整。\n\n6. 推動經濟增長模式轉變:\n從長遠來看,AI技術的發展可能會推動中國經濟從要素驅動向創新驅動轉變。\n\n7. 提振市場信心:\nDeepSeek的成功在一定程度上提振了市場對中國科技創新能力的信心,可能會吸引更多投資。\n\n8. 面臨挑戰:\nAI的快速發展也可能帶來數據安全、就業衝擊等挑戰,需要政府制定相應政策加以應對。\n\n總的來說,DeepSeek的出現可能會加速中國經濟的數字化轉型,推動產業升級,但同時也需要應對可能帶來的挑戰。它的長期影響還有待進一步觀察。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None), delta={'role': 'assistant', 'content': ''})], created=1741334307, model='sonar-pro', object='chat.compl
# ...

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=989, prompt_tokens=37, total_tokens=1026, completion_tokens_details=None, prompt_tokens_details=None, citation_tokens=4127, num_search_queries=1)

# %%
#stream = False
answer = response.choices[0].message.content
citations = response.citations
with open("deepseek_china_sonar-reasoning-pro.txt", "w") as file:
    file.write(str(response.usage) + "\n\n")
    file.write(answer)
    file.write("\n\n\n Citations \n")
    for i, cit in enumerate(citations):
        file.write(str(i+1)+" " + cit + "\n")

# %%
#Combining chunks when stream = True
answer = ""
for chunk in chunks:
    answer+=chunk.choices[0].delta.content
with open("q11_sonarpro_log.txt", "w") as file:
    file.write(answer)
